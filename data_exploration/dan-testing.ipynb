# %% [markdown]
# ## Packages and default settings
#
# In particular, there is a setting for how many rows to load. The database is MASSIVE.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import sqlite3
import time
import sys

MAX_ROWS = 10*1000*1000
path = "../data/melee_player_database.db"

# %% [markdown]
# ## Load the database

# %%
con = sqlite3.connect(path)
cur = con.cursor()

# Might be slightly janky
def get_column_names(table):
    cur.execute("SELECT * FROM " + table + " LIMIT 1")
    return [x[0] for x in cur.description]

def get_rows(table, max_rows=None):
    if max_rows is None:
        cur.execute("SELECT * FROM " + table)
    else:
        cur.execute("SELECT * FROM " + table + " LIMIT " + str(max_rows))
    
    return cur.fetchall()

def load_table(table, max_rows=None):
    # BENCHMARKING - BENCHMARKING - BENCHMARKING
    start_time = time.time()
    
    columns = get_column_names(table)
    rows = get_rows(table=table, max_rows=MAX_ROWS)
    
    df = pd.DataFrame(rows, columns=columns)
    
    # BENCHMARKING - BENCHMARKING - BENCHMARKING
    print("--- Table: {0} ---".format(table))
    print("--- Duration of {0:.2f} seconds ---".format(time.time() - start_time))
    print("--- Memory size of {0:.2f} MB ---".format(float(sys.getsizeof(df)) / (1024*1024)))
    print("--- Total of {0} rows ---".format(len(df.index)))
    print("")

    return df

# Load tables. Only sets is massive. No need to limit ourselves on the rest.
df_sets            = load_table("sets", MAX_ROWS)
df_tournament_info = load_table("tournament_info")
df_players         = load_table("players")
df_ranking_seasons = load_table("ranking_seasons")
df_ranking         = load_table("ranking")
# Out:
# --- Table: sets ---
# --- Duration of 6.10 seconds ---
# --- Memory size of 1442.36 MB ---
# --- Total of 1795681 rows ---
#
# --- Table: tournament_info ---
# --- Duration of 0.41 seconds ---
# --- Memory size of 159.14 MB ---
# --- Total of 39675 rows ---
#
# --- Table: players ---
# --- Duration of 0.37 seconds ---
# --- Memory size of 142.89 MB ---
# --- Total of 96689 rows ---
#
# --- Table: ranking_seasons ---
# --- Duration of 0.00 seconds ---
# --- Memory size of 0.01 MB ---
# --- Total of 5 rows ---
#
# --- Table: ranking ---
# --- Duration of 0.00 seconds ---
# --- Memory size of 0.00 MB ---
# --- Total of 1 rows ---

# %%
df_sets.head(1)
# Out:
#          key   game                             tournament_key winner_id  \
# 0  104675843  melee  mdva-invitational-2017-(challonge-mirror)      5620
#
#   p1_id    p2_id  p1_score  p2_score                location_names  \
# 0  5620  Chillin         3         1  ["R1", "Round 1", "Round 1"]
#
#   bracket_name bracket_order set_order  best_of game_data
# 0                          1         A      5.0        []

# %%
df_tournament_info.head(1)
# Out:
#     game                                        key  \
# 0  melee  mdva-invitational-2017-(challonge-mirror)
#
#                                 cleaned_name     source  \
# 0  MDVA Invitational 2017 (Challonge Mirror)  challonge
#
#                                 tournament_name tournament_event season rank  \
# 0  https://challonge.com/mdva_invitational_2017                      17
#
#         start         end country state           city  entrants  \
# 0  1511683511  1511686089      US    VA  Fall's Church        10
#
#                                             placings losses bracket_types  \
# 0  [\n  [\n    "Rishi",\n    1\n  ],\n  [\n    15...     {}         b'{}'
#
#    online  lat  lng
# 0       0  NaN  NaN

# %%
df_players.head(1)
# Out:
#     game player_id    tag   all_tags prefixes           social country state  \
# 0  melee     Rishi  Rishi  ["Rishi"]       []  {"twitter": []}
#
#   region c_country c_state c_region  \
# 0             None    None     None
#
#                                             placings characters alias
# 0  [{"key": "mdva-invitational-2017-(challonge-mi...         ""  None

# %%
df_ranking.head(1)
# Out:
#     game ranking_name  priority region  \
# 0  melee     SSBMRank         0  world
#
#                                     seasons tournaments  icon
# 0  ["2015", "2016", "2017", "2018", "2019"]          []  miom

# %%
df_ranking_seasons.head(1)
# Out:
#     game ranking_name season       start         end  total  \
# 0  melee     SSBMRank   2015  1420070400  1451606399    100
#
#                                                by_id  \
# 0  {"6189": 1, "1004": 2, "4465": 3, "1000": 4, "...
#
#                                           by_placing  final  name
# 0  {"1": "6189", "2": "1004", "3": "4465", "4": "...      0  None

# %% [markdown]
# ## Combine some relevant info into one table
#
# Here, for convenience, we will consider most of the set info together with the tournament dates (unix time) and player tags.

# %%
df_past_wins = df_sets[['key', 'tournament_key', 'winner_id', 'p1_id', 'p2_id', 'p1_score', 'p2_score', 'best_of', 'location_names']]

# Add tournament start/end, sort in chronological order
df_past_wins = df_past_wins.merge(df_tournament_info[['key', 'start', 'end']], left_on='tournament_key', right_on='key', how='left')
df_past_wins = df_past_wins.drop(labels=['key_y'], axis='columns')
df_past_wins = df_past_wins.rename(columns={"key_x": "key"})
df_past_wins = df_past_wins.sort_values(by=['start', 'end'])

# Add player tags, for convenience when looking up the info online
df_past_wins = df_past_wins.merge(df_players[['player_id', 'tag']], left_on='p1_id', right_on='player_id', how='left')
df_past_wins = df_past_wins.drop(labels=['player_id'], axis='columns')
df_past_wins = df_past_wins.rename(columns={"tag": "p1_tag"})

df_past_wins = df_past_wins.merge(df_players[['player_id', 'tag']], left_on='p2_id', right_on='player_id', how='left')
df_past_wins = df_past_wins.drop(labels=['player_id'], axis='columns')
df_past_wins = df_past_wins.rename(columns={"tag": "p2_tag"})

df_past_wins
# Out:
#                   key                                     tournament_key  \
# 0        gg__36789317  pooperbowl-ii-lula-birthday-bash__redemption-f...
# 1        gg__36789318  pooperbowl-ii-lula-birthday-bash__redemption-f...
# 2        gg__36789319  pooperbowl-ii-lula-birthday-bash__redemption-f...
# 3        gg__36789320  pooperbowl-ii-lula-birthday-bash__redemption-f...
# 4        gg__36789321  pooperbowl-ii-lula-birthday-bash__redemption-f...
# ...               ...                                                ...
# 1795676  gg__76275446                         naonline-21__melee-singles
# 1795677  gg__76275447                         naonline-21__melee-singles
# 1795678  gg__76275448                         naonline-21__melee-singles
# 1795679  gg__76275453                         naonline-21__melee-singles
# 1795680  gg__76275454                         naonline-21__melee-singles
#
#         winner_id    p1_id    p2_id  p1_score  p2_score  best_of  \
# 0         2058790  2117535  2058790         0         2      3.0
# 1         1377847  1063082  1377847         0         2      3.0
# 2           62672  2239416    62672         0         2      3.0
# 3         2165165  2165165   264336         0        -1      3.0
# 4         1377847  2058790  1377847         0         2      3.0
# ...           ...      ...      ...       ...       ...      ...
# 1795676   2092907  2092907  3137063         3         2      5.0
# 1795677   3137063  2092907  3137063         1         3      5.0
# 1795678   2092907  3137063  2092907        -1         0      5.0
# 1795679   2558872  3910942  2558872         0         3      5.0
# 1795680   3137063  3137063  2558872         3         0      5.0
#
#                                             location_names       start  \
# 0        ["WQF", "Winners Quarters", "Winners Quarter-F...   987565500
# 1        ["WQF", "Winners Quarters", "Winners Quarter-F...   987565500
# 2        ["WQF", "Winners Quarters", "Winners Quarter-F...   987565500
# 3        ["WQF", "Winners Quarters", "Winners Quarter-F...   987565500
# 4           ["WSF", "Winners Semis", "Winners Semi-Final"]   987565500
# ...                                                    ...         ...
# 1795676           ["WF", "Winners Final", "Winners Final"]  1719147600
# 1795677               ["GF", "Grand Final", "Grand Final"]  1719147600
# 1795678           ["GFR", "GF Reset", "Grand Final Reset"]  1719147600
# 1795679       ["LSF", "Losers Semis", "Losers Semi-Final"]  1719147600
# 1795680             ["LF", "Losers Final", "Losers Final"]  1719147600
#
#                 end        p1_tag      p2_tag
# 0        1618718400           vel  Butternust
# 1        1618718400        tilted     Niaki17
# 2        1618718400         steib       zubbs
# 3        1618718400  Senseovernet         TBA
# 4        1618718400    Butternust     Niaki17
# ...             ...           ...         ...
# 1795676  1719176400       armando         Lwi
# 1795677  1719176400       armando         Lwi
# 1795678  1719176400           Lwi     armando
# 1795679  1719176400          nyts     GokhanZ
# 1795680  1719176400           Lwi     GokhanZ
#
# [1795681 rows x 13 columns]

# %% [markdown]
# ## Data cleanup
#
# Immediately, in the above, we notice that
# * There are some entries with an unusually early ``start`` for the tournament. These are few and can be safely deleted.
# * Some entries have a negative ``p1_score`` or ``p2_score``.

# %%
# Some of this seems to accidentally be 2001 data, despite the purported end date.
print("Total of {0} rows with unusually early start date".format(len(df_past_wins[df_past_wins['start'] < 1388534400].index)))

df_past_wins = df_past_wins[df_past_wins['start'] >= 1388534400]

# Some sets have a negative score?
num_negative = len(df_past_wins[(df_past_wins['p1_score'] < 0) | (df_past_wins['p2_score'] < 0)].index)
num_total = len(df_past_wins.index)
print("{0:.2f}% have a negative score somewhere".format(100 * num_negative / num_total))

df_past_wins = df_past_wins[(df_past_wins['p1_score'] >= 0) & (df_past_wins['p2_score'] >= 0)]

df_past_wins
# Out:
# Total of 14 rows with unusually early start date
# 10.08% have a negative score somewhere
#                   key                    tournament_key winner_id       p1_id  \
# 14                     httpsbeastsmashchallongecomb5msb      1000        1000
# 15                     httpsbeastsmashchallongecomb5msb       IVP  Flikkflakk
# 16                     httpsbeastsmashchallongecomb5msb     Humpe       Humpe
# 17                     httpsbeastsmashchallongecomb5msb    Thomas      Thomas
# 18                     httpsbeastsmashchallongecomb5msb     12870       12870
# ...               ...                               ...       ...         ...
# 1795675  gg__76275445        naonline-21__melee-singles   3137063     2558872
# 1795676  gg__76275446        naonline-21__melee-singles   2092907     2092907
# 1795677  gg__76275447        naonline-21__melee-singles   3137063     2092907
# 1795679  gg__76275453        naonline-21__melee-singles   2558872     3910942
# 1795680  gg__76275454        naonline-21__melee-singles   3137063     3137063
#
#              p2_id  p1_score  p2_score  best_of  \
# 14         Stelzig         2         0      3.0
# 15             IVP         0         2      3.0
# 16            Yomi         2         0      3.0
# 17             Hao         2         0      3.0
# 18       JJLinyard         2         0      3.0
# ...            ...       ...       ...      ...
# 1795675    3137063         0         3      5.0
# 1795676    3137063         3         2      5.0
# 1795677    3137063         1         3      5.0
# 1795679    2558872         0         3      5.0
# 1795680    2558872         3         0      5.0
#
#                                          location_names       start  \
# 14               ["W1", "Winners 1", "Winners Round 1"]  1420985773
# 15               ["W1", "Winners 1", "Winners Round 1"]  1420985773
# 16               ["W1", "Winners 1", "Winners Round 1"]  1420985773
# 17               ["W1", "Winners 1", "Winners Round 1"]  1420985773
# 18               ["W1", "Winners 1", "Winners Round 1"]  1420985773
# ...                                                 ...         ...
# 1795675  ["WSF", "Winners Semis", "Winners Semi-Final"]  1719147600
# 1795676        ["WF", "Winners Final", "Winners Final"]  1719147600
# 1795677            ["GF", "Grand Final", "Grand Final"]  1719147600
# 1795679    ["LSF", "Losers Semis", "Losers Semi-Final"]  1719147600
# 1795680          ["LF", "Losers Final", "Losers Final"]  1719147600
#
#                 end      p1_tag     p2_tag
# 14       1421110948       Mang0    Stelzig
# 15       1421110948  Flikkflakk        IVP
# 16       1421110948       Humpe       Yomi
# 17       1421110948      Thomas        Hao
# 18       1421110948     Android  JJLinyard
# ...             ...         ...        ...
# 1795675  1719176400     GokhanZ        Lwi
# 1795676  1719176400     armando        Lwi
# 1795677  1719176400     armando        Lwi
# 1795679  1719176400        nyts    GokhanZ
# 1795680  1719176400         Lwi    GokhanZ
#
# [1614634 rows x 13 columns]

# %% [markdown]
# ## More data cleanup, this time in players
#
# It appears as if the same player can have several different ids, as can be seen with the following example.

# %%
# Ex: "["Zain", "DontTestMe"]"

tag = "Zain"

def str_to_array(s):
    s = s.replace('[', '').replace(']', '')
    
    elements = s.split(',')
    elements = [e.strip().replace('\'','').replace('\"','') for e in elements]

    return elements

df_specific_tag = df_players[df_players['all_tags'].apply(lambda x: tag in str_to_array(x))]

df_specific_tag

#for p in df_specific_tag['placings']:
#    print(p)
# Out:
#         game player_id       tag  \
# 102    melee      1000     Mang0
# 38507  melee    330371     Sol!d
# 44464  melee   2396108  Lean_dad
# 57296  melee    148442     Mang0
# 77494  melee   1456076    Leffen
#
#                                                 all_tags        prefixes  \
# 102    ["C9 | Mango", "Mango", "C9. Mango", "C9|Mango...          ["C9"]
# 38507                                 ["Sol!d", "Mang0"]  ["W&L", "SMB"]
# 44464                              ["Mang0", "Lean_dad"]              []
# 57296                                          ["Mang0"]          ["C9"]
# 77494                 ["Mang0", "Cody Schwab", "Leffen"]   ["C9", "TSM"]
#
#                          social        country state region c_country  \
# 102    {"twitter": ["C9Mang0"]}  United States    CA  SoCal        US
# 38507           {"twitter": []}        Uruguay  None   None        UY
# 44464           {"twitter": []}  United States    PA   None        US
# 57296           {"twitter": []}  United States    CA   None        US
# 77494           {"twitter": []}  United States    CA   None        US
#
#                      c_state     c_region  \
# 102                       CA  Los Angeles
# 38507  Montevideo Department   Montevideo
# 44464                     PA         None
# 57296                     CA         None
# 77494                     CA      Benicia
#
#                                                 placings  \
# 102    [{"key": "slippi-champions-league-week-1__mele...
# 38507  [{"key": "montevideo-melee-monthly-2021-1__mel...
# 44464  [{"key": "2021-philly-melee-arcadian-the-lab__...
# 57296  [{"key": "c9-mang0-5-2-stock-side-event__two-s...
# 77494  [{"key": "blg-smash-tarn-36__melee-singles", "...
#
#                                               characters alias
# 102    {"melee/falco": 812, "melee/fox": 516, "melee/...  None
# 38507  {"melee/captainfalcon": 124, "melee/mario": 39...  None
# 44464                                                 ""  None
# 57296                                                 ""  None
# 77494                                                 ""  None
